# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## Importing Data

# %%
#create path
path = r'C:\Users\smerg\Instacart Grocery Basket Analysis'
#combined data
df_ords_combined = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))
#cleaned producted data
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_checked.csv'), index_col = False)

# %%
df_ords_combined.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2539329        1    prior             1          2                  8
# 2   2539329        1    prior             1          2                  8
# 3   2539329        1    prior             1          2                  8
# 4   2539329        1    prior             1          2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both

# %%
df_ords_combined.shape
# Out:
# (32434489, 11)

# %%
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
df_prods.shape
# Out:
# (49677, 6)

# %%
#Drop unnamed columns in df_prods
df_prods = df_prods.drop(columns = ['Unnamed: 0'])

# %%
#Drop unnamed columns in df_ords_combined
df_ords_combined = df_ords_combined.drop(columns = ['_merge'])

# %%
#Merge df_prods and df_ords_combined
df_merged = df_prods.merge(df_ords_combined, on = 'product_id', indicator = True)

# %%
df_merged.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   3139998      138    prior            28          6                 11
# 1   1977647      138    prior            30          6                 17
# 2    389851      709    prior             2          0                 21
# 3    652770      764    prior             1          3                 13
# 4   1813452      764    prior             3          4                 17
#
#    days_since_prior_order  add_to_cart_order  reordered _merge
# 0                     3.0                  5          0   both
# 1                    20.0                  1          1   both
# 2                     6.0                 20          0   both
# 3                     NaN                 10          0   both
# 4                     9.0                 11          1   both

# %%
df_merged
# Out:
#           product_id                product_name  aisle_id  department_id  \
# 0                  1  Chocolate Sandwich Cookies        61             19
# 1                  1  Chocolate Sandwich Cookies        61             19
# 2                  1  Chocolate Sandwich Cookies        61             19
# 3                  1  Chocolate Sandwich Cookies        61             19
# 4                  1  Chocolate Sandwich Cookies        61             19
# ...              ...                         ...       ...            ...
# 32406036       49688      Fresh Foaming Cleanser        73             11
# 32406037       49688      Fresh Foaming Cleanser        73             11
# 32406038       49688      Fresh Foaming Cleanser        73             11
# 32406039       49688      Fresh Foaming Cleanser        73             11
# 32406040       49688      Fresh Foaming Cleanser        73             11
#
#           prices  order_id  user_id eval_set  order_number  order_dow  \
# 0            5.8   3139998      138    prior            28          6
# 1            5.8   1977647      138    prior            30          6
# 2            5.8    389851      709    prior             2          0
# 3            5.8    652770      764    prior             1          3
# 4            5.8   1813452      764    prior             3          4
# ...          ...       ...      ...      ...           ...        ...
# 32406036    13.5   1788356   200215    prior             2          0
# 32406037    13.5   3401313   200377    prior             1          4
# 32406038    13.5    809510   200873    prior             5          3
# 32406039    13.5   2359893   200873    prior             9          3
# 32406040    13.5   2385091   205926    prior            11          1
#
#           order_hour_of_day  days_since_prior_order  add_to_cart_order  \
# 0                        11                     3.0                  5
# 1                        17                    20.0                  1
# 2                        21                     6.0                 20
# 3                        13                     NaN                 10
# 4                        17                     9.0                 11
# ...                     ...                     ...                ...
# 32406036                  9                     5.0                 27
# 32406037                 11                     NaN                  5
# 32406038                  8                    15.0                 12
# 32406039                 15                     5.0                 11
# 32406040                 15                     6.0                 35
#
#           reordered _merge
# 0                 0   both
# 1                 1   both
# 2                 0   both
# 3                 0   both
# 4                 1   both
# ...             ...    ...
# 32406036          0   both
# 32406037          0   both
# 32406038          0   both
# 32406039          1   both
# 32406040          0   both
#
# [32406041 rows x 15 columns]

# %%
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   3139998      138    prior            28          6                 11
# 1   1977647      138    prior            30          6                 17
# 2    389851      709    prior             2          0                 21
# 3    652770      764    prior             1          3                 13
# 4   1813452      764    prior             3          4                 17
#
#    days_since_prior_order  add_to_cart_order  reordered _merge
# 0                     3.0                  5          0   both
# 1                    20.0                  1          1   both
# 2                     6.0                 20          0   both
# 3                     NaN                 10          0   both
# 4                     9.0                 11          1   both

# %%
df_merged['_merge'].value_counts()
# Out:
# _merge
# both          32406041
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
#Export orders_products_merged file
df_merged.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))
